# %% [markdown]
# # Ex1 - Filtering and Sorting Data

# %% [markdown]
# ## 2025-06-14 복습 필요 - TypeError: 'float' object is not subscriptable

# %% [markdown]
# This time we are going to pull data directly from the internet.
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv).

# %% [markdown]
# ### Step 3. Assign it to a variable called chipo.

# %%
url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv'

chipo = pd.read_csv(url, sep = '\t')

# %% [markdown]
# ### Step 4. How many products cost more than $10.00?

# %%
chipo.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
chipo['quantity'].dtype
# Out:
# dtype('int64')

# %%
print(chipo.item_price.head(10))
# Out:
# 0     $2.39
# 1     $3.39
# 2     $3.39
# 3     $2.39
# 4    $16.98
# 5    $10.98
# 6     $1.69
# 7    $11.75
# 8     $9.25
# 9     $9.25
# Name: item_price, dtype: object

# %%
chipo['item_price'] = chipo['item_price'].astype(str).str.replace('$', '').astype(float)

# %%
# quantity 타입 확인 및 변환
print("quantity 타입:", chipo['quantity'].dtype)
chipo['quantity'] = chipo['quantity'].astype(int)

# 중복 제거 (컬럼명 확인 필요)
print("컬럼명 확인:", chipo.columns.tolist())
chipo_filtered = chipo.drop_duplicates(['item_name', 'quantity', 'choice_description'])

# 수량이 1인 상품만 필터링
chipo_one_prod = chipo_filtered[chipo_filtered.quantity == 1]

# 결과 확인
print(f"가격이 10달러 이상인 상품 종류 수: {chipo_one_prod[chipo_one_prod['item_price'] > 10].item_name.nunique()}")
print(chipo_one_prod[chipo_one_prod['item_price'] > 10])
# Out:
# quantity 타입: int64
# 컬럼명 확인: ['order_id', 'quantity', 'item_name', 'choice_description', 'item_price']
# 가격이 10달러 이상인 상품 종류 수: 25
#       order_id  quantity        item_name  \
# 5            3         1     Chicken Bowl
# 7            4         1    Steak Burrito
# 13           7         1     Chicken Bowl
# 23          12         1  Chicken Burrito
# 39          19         1    Barbacoa Bowl
# ...        ...       ...              ...
# 4593      1825         1    Carnitas Bowl
# 4594      1825         1    Barbacoa Bowl
# 4607      1829         1    Steak Burrito
# 4610      1830         1    Steak Burrito
# 4611      1830         1   Veggie Burrito
#
#                                      choice_description  item_price
# 5     [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...       10.98
# 7     [Tomatillo Red Chili Salsa, [Fajita Vegetables...       11.75
# 13    [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...       11.25
# ...

# %% [markdown]
# ### Step 5. What is the price of each item?
# ###### print a data frame with only two columns item_name and item_price

# %%
chipo_filtered = chipo.drop_duplicates(['item_name', 'quantity'])
chipo[(chipo['item_name'] == 'Chicken Bowl') & (chipo['quantity'] == 1)]
# Out:
#       order_id  quantity     item_name  \
# 5            3         1  Chicken Bowl
# 13           7         1  Chicken Bowl
# 19          10         1  Chicken Bowl
# 26          13         1  Chicken Bowl
# 42          20         1  Chicken Bowl
# ...        ...       ...           ...
# 4590      1825         1  Chicken Bowl
# 4591      1825         1  Chicken Bowl
# 4595      1826         1  Chicken Bowl
# 4599      1827         1  Chicken Bowl
# 4604      1828         1  Chicken Bowl
#
#                                      choice_description  item_price
# 5     [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...       10.98
# 13    [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...       11.25
# 19    [Tomatillo Red Chili Salsa, [Fajita Vegetables...        8.75
# 26    [Roasted Chili Corn Salsa (Medium), [Pinto Bea...        8.49
# 42    [Roasted Chili Corn Salsa, [Rice, Black Beans,...       11.25
# ...                                                 ...         ...
# ...

# %% [markdown]
# ### Step 6. Sort by the name of the item

# %%
chipo.item_name.sort_values()
# Out:
# 3389    6 Pack Soft Drink
# 341     6 Pack Soft Drink
# 1849    6 Pack Soft Drink
# 1860    6 Pack Soft Drink
# 2713    6 Pack Soft Drink
#               ...
# 2384    Veggie Soft Tacos
# 781     Veggie Soft Tacos
# 2851    Veggie Soft Tacos
# 1699    Veggie Soft Tacos
# 1395    Veggie Soft Tacos
# Name: item_name, Length: 4622, dtype: object

# %% [markdown]
# ### Step 7. What was the quantity of the most expensive item ordered?

# %%
chipo.sort_values(by = 'item_price', ascending = False).head(1)
# Out:
#       order_id  quantity                     item_name choice_description  \
# 3598      1443        15  Chips and Fresh Tomato Salsa                NaN
#
#       item_price
# 3598       44.25

# %% [markdown]
# ### Step 8. How many times was a Veggie Salad Bowl ordered?

# %%
chipo_salad = chipo[chipo.item_name == 'Veggie Salad Bowl']
len(chipo_salad)
# Out:
# 18

# %% [markdown]
# ### Step 9. How many times did someone order more than one Canned Soda?

# %%
chipo_canned_soda_any = chipo[(chipo.item_name == "Canned Soda") & (chipo.quantity >= 1)]
print(f"1개 이상 주문한 횟수: {len(chipo_canned_soda_any)}")
# Out:
# 1개 이상 주문한 횟수: 104
